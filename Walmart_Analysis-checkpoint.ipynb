# %%
import pandas as pd

# %%
df = pd.read_csv('Walmart.csv')
df
# Out:
#        invoice_id   Branch         City                category unit_price  \
# 0               1  WALM003  San Antonio       Health and beauty     $74.69
# 1               2  WALM048    Harlingen  Electronic accessories     $15.28
# 2               3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3               4  WALM064      Bedford       Health and beauty     $58.22
# 4               5  WALM013       Irving       Sports and travel     $86.31
# ...           ...      ...          ...                     ...        ...
# 10046        9996  WALM056      Rowlett     Fashion accessories        $37
# 10047        9997  WALM030   Richardson      Home and lifestyle        $58
# 10048        9998  WALM050     Victoria     Fashion accessories        $52
# 10049        9999  WALM032        Tyler      Home and lifestyle        $79
# 10050       10000  WALM069     Rockwall     Fashion accessories        $62
#
# ...

# %%
df.sample(5)
# Out:
#       invoice_id   Branch         City                category unit_price  \
# 586          587  WALM038   Sugar Land      Food and beverages     $52.34
# 9072        9073  WALM058  Port Arthur      Home and lifestyle        $83
# 45            46  WALM056      Rowlett  Electronic accessories     $93.96
# 9009        9010  WALM075   San Marcos     Fashion accessories        $69
# 4404        4405  WALM030   Richardson      Home and lifestyle        $85
#
#       quantity      date      time payment_method  rating  profit_margin
# 586        3.0  27/03/19  14:03:00           Cash     9.2           0.48
# 9072       2.0  01/03/22  16:17:00           Cash     5.0           0.33
# 45         4.0  09/03/19  18:00:00           Cash     9.5           0.33
# 9009       3.0  27/10/23  11:48:00           Cash     7.0           0.33
# 4404       1.0  19/09/21  18:57:00        Ewallet     5.0           0.48

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10051 entries, 0 to 10050
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      10051 non-null  int64
#  1   Branch          10051 non-null  object
#  2   City            10051 non-null  object
#  3   category        10051 non-null  object
#  4   unit_price      10020 non-null  object
#  5   quantity        10020 non-null  float64
#  6   date            10051 non-null  object
#  7   time            10051 non-null  object
#  8   payment_method  10051 non-null  object
#  9   rating          10051 non-null  float64
#  10  profit_margin   10051 non-null  float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 863.9+ KB

# %% [markdown]
# - I have null values in 2 columns

# %%
df.head()
# Out:
#    invoice_id   Branch         City                category unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty     $74.69
# 1           2  WALM048    Harlingen  Electronic accessories     $15.28
# 2           3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3           4  WALM064      Bedford       Health and beauty     $58.22
# 4           5  WALM013       Irving       Sports and travel     $86.31
#
#    quantity      date      time payment_method  rating  profit_margin
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48

# %%
df.shape
# Out:
# (10051, 11)

# %%
df.describe()
# Out:
#          invoice_id      quantity        rating  profit_margin
# count  10051.000000  10020.000000  10051.000000   10051.000000
# mean    5025.741220      2.353493      5.825659       0.393791
# std     2901.174372      1.602658      1.763991       0.090669
# min        1.000000      1.000000      3.000000       0.180000
# 25%     2513.500000      1.000000      4.000000       0.330000
# 50%     5026.000000      2.000000      6.000000       0.330000
# 75%     7538.500000      3.000000      7.000000       0.480000
# max    10000.000000     10.000000     10.000000       0.570000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10051 entries, 0 to 10050
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      10051 non-null  int64
#  1   Branch          10051 non-null  object
#  2   City            10051 non-null  object
#  3   category        10051 non-null  object
#  4   unit_price      10020 non-null  object
#  5   quantity        10020 non-null  float64
#  6   date            10051 non-null  object
#  7   time            10051 non-null  object
#  8   payment_method  10051 non-null  object
#  9   rating          10051 non-null  float64
#  10  profit_margin   10051 non-null  float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 863.9+ KB

# %%
df.isnull().mean()*100
# Out:
# invoice_id        0.000000
# Branch            0.000000
# City              0.000000
# category          0.000000
# unit_price        0.308427
# quantity          0.308427
# date              0.000000
# time              0.000000
# payment_method    0.000000
# rating            0.000000
# profit_margin     0.000000
# dtype: float64

# %%
#checking for duplicate values
df.duplicated().sum()
# Out:
# 51

# %% [markdown]
# - I have 51 duplicate values

# %%
#Droping the duplicate values
df.drop_duplicates(inplace = True)
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - I have droped duplicate values as shown above 0 duplicate values

# %%
#Checking for null values
df.isnull().sum()
# Out:
# invoice_id         0
# Branch             0
# City               0
# category           0
# unit_price        31
# quantity          31
# date               0
# time               0
# payment_method     0
# rating             0
# profit_margin      0
# dtype: int64

# %% [markdown]
# - I have total 62 null values in 2 Columns

# %%
#Droping for null values with missing record
df.dropna(inplace = True)

#Verify
df.isna().sum()
# Out:
# invoice_id        0
# Branch            0
# City              0
# category          0
# unit_price        0
# quantity          0
# date              0
# time              0
# payment_method    0
# rating            0
# profit_margin     0
# dtype: int64

# %% [markdown]
# - I have droped null values with missing record

# %%
df.shape
# Out:
# (9969, 11)

# %%
#Changing the datatype of date
df['date'] = pd.to_datetime(df['date'], format = '%d/%m/%y')

# %%
df['day'] = df['date'].dt.day

# %%
df
# Out:
#       invoice_id   Branch         City                category unit_price  \
# 0              1  WALM003  San Antonio       Health and beauty     $74.69
# 1              2  WALM048    Harlingen  Electronic accessories     $15.28
# 2              3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3              4  WALM064      Bedford       Health and beauty     $58.22
# 4              5  WALM013       Irving       Sports and travel     $86.31
# ...          ...      ...          ...                     ...        ...
# 9995        9996  WALM056      Rowlett     Fashion accessories        $37
# 9996        9997  WALM030   Richardson      Home and lifestyle        $58
# 9997        9998  WALM050     Victoria     Fashion accessories        $52
# 9998        9999  WALM032        Tyler      Home and lifestyle        $79
# 9999       10000  WALM069     Rockwall     Fashion accessories        $62
#
#       quantity       date      time payment_method  rating  profit_margin  day
# ...

# %%
df['month'] = df['date'].dt.month_name()

# %%
df
# Out:
#       invoice_id   Branch         City                category unit_price  \
# 0              1  WALM003  San Antonio       Health and beauty     $74.69
# 1              2  WALM048    Harlingen  Electronic accessories     $15.28
# 2              3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3              4  WALM064      Bedford       Health and beauty     $58.22
# 4              5  WALM013       Irving       Sports and travel     $86.31
# ...          ...      ...          ...                     ...        ...
# 9995        9996  WALM056      Rowlett     Fashion accessories        $37
# 9996        9997  WALM030   Richardson      Home and lifestyle        $58
# 9997        9998  WALM050     Victoria     Fashion accessories        $52
# 9998        9999  WALM032        Tyler      Home and lifestyle        $79
# 9999       10000  WALM069     Rockwall     Fashion accessories        $62
#
#       quantity       date      time payment_method  rating  profit_margin  \
# ...

# %%
df['quarter'] = df['date'].dt.quarter

# %%
df
# Out:
#       invoice_id   Branch         City                category unit_price  \
# 0              1  WALM003  San Antonio       Health and beauty     $74.69
# 1              2  WALM048    Harlingen  Electronic accessories     $15.28
# 2              3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3              4  WALM064      Bedford       Health and beauty     $58.22
# 4              5  WALM013       Irving       Sports and travel     $86.31
# ...          ...      ...          ...                     ...        ...
# 9995        9996  WALM056      Rowlett     Fashion accessories        $37
# 9996        9997  WALM030   Richardson      Home and lifestyle        $58
# 9997        9998  WALM050     Victoria     Fashion accessories        $52
# 9998        9999  WALM032        Tyler      Home and lifestyle        $79
# 9999       10000  WALM069     Rockwall     Fashion accessories        $62
#
#       quantity       date      time payment_method  rating  profit_margin  \
# ...

# %% [markdown]
# - I have changed the dtype of date in datetime dtype, Standarized the date format and extract day, month and quarter

# %%
#Changing dtype of 'unit_price' column
df['unit_price'] = df['unit_price'].str.replace('$' , '')

df['unit_price'] = df['unit_price'].astype(float)

print(df['unit_price'].dtype)
# Out:
# float64

# %% [markdown]
# - I have changed the dtype of 'unit_price' column into float also removed $ symbol

# %%
df.head()
# Out:
#    invoice_id   Branch         City                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity       date      time payment_method  rating  profit_margin  day  \
# 0       7.0 2019-01-05  13:08:00        Ewallet     9.1           0.48    5
# 1       5.0 2019-03-08  10:29:00           Cash     9.6           0.48    8
# 2       7.0 2019-03-03  13:23:00    Credit card     7.4           0.33    3
# 3       8.0 2019-01-27  20:33:00        Ewallet     8.4           0.33   27
# 4       7.0 2019-02-08  10:37:00        Ewallet     5.3           0.48    8
#
#       month  quarter
# 0   January        1
# 1     March        1
# ...

# %% [markdown]
# - I have changed the 'profit_margin' column's decimal number to whole number

# %%
df.head()
# Out:
#    invoice_id   Branch         City                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity       date      time payment_method  rating  profit_margin  day  \
# 0       7.0 2019-01-05  13:08:00        Ewallet     9.1           0.48    5
# 1       5.0 2019-03-08  10:29:00           Cash     9.6           0.48    8
# 2       7.0 2019-03-03  13:23:00    Credit card     7.4           0.33    3
# 3       8.0 2019-01-27  20:33:00        Ewallet     8.4           0.33   27
# 4       7.0 2019-02-08  10:37:00        Ewallet     5.3           0.48    8
#
#       month  quarter
# 0   January        1
# 1     March        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9969 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      9969 non-null   int64
#  1   Branch          9969 non-null   object
#  2   City            9969 non-null   object
#  3   category        9969 non-null   object
#  4   unit_price      9969 non-null   float64
#  5   quantity        9969 non-null   float64
#  6   date            9969 non-null   datetime64[ns]
#  7   time            9969 non-null   object
#  8   payment_method  9969 non-null   object
#  9   rating          9969 non-null   float64
#  10  profit_margin   9969 non-null   float64
#  11  day             9969 non-null   int32
#  12  month           9969 non-null   object
#  13  quarter         9969 non-null   int32
# dtypes: datetime64[ns](1), float64(4), int32(2), int64(1), object(6)
# memory usage: 1.1+ MB

# %%
#Making it in a lower case
df.columns = df.columns.str.lower()
df.head()
# Out:
#    invoice_id   branch         city                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity       date      time payment_method  rating  profit_margin  day  \
# 0       7.0 2019-01-05  13:08:00        Ewallet     9.1           0.48    5
# 1       5.0 2019-03-08  10:29:00           Cash     9.6           0.48    8
# 2       7.0 2019-03-03  13:23:00    Credit card     7.4           0.33    3
# 3       8.0 2019-01-27  20:33:00        Ewallet     8.4           0.33   27
# 4       7.0 2019-02-08  10:37:00        Ewallet     5.3           0.48    8
#
#       month  quarter
# 0   January        1
# 1     March        1
# ...

# %% [markdown]
# - I have make the columns names into lower case as it was in a improper way before

# %%
df.columns
# Out:
# Index(['invoice_id', 'branch', 'city', 'category', 'unit_price', 'quantity',
#        'date', 'time', 'payment_method', 'rating', 'profit_margin', 'day',
#        'month', 'quarter'],
#       dtype='object')

# %%
#creating a new column 'total'
df['total'] = df['unit_price'] * df['quantity']
df.head(5)
# Out:
#    invoice_id   branch         city                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity       date      time payment_method  rating  profit_margin  day  \
# 0       7.0 2019-01-05  13:08:00        Ewallet     9.1           0.48    5
# 1       5.0 2019-03-08  10:29:00           Cash     9.6           0.48    8
# 2       7.0 2019-03-03  13:23:00    Credit card     7.4           0.33    3
# 3       8.0 2019-01-27  20:33:00        Ewallet     8.4           0.33   27
# 4       7.0 2019-02-08  10:37:00        Ewallet     5.3           0.48    8
#
#       month  quarter   total
# 0   January        1  522.83
# ...

# %% [markdown]
# - I have created a new column of 'total' by * the 'unit_price' & 'quantity' columns with each other

# %%
pip install pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\admin\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import pyodbc

cnxn = pyodbc.connect(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=DESKTOP-3D3ET4P\\SQLEXPRESS;"
    "Database=Demo;"
    "Trusted_Connection=yes;"
)

cursor = cnxn.cursor()

cursor.execute("Select * from Walmart")
rows = cursor.fetchall()

print(rows)
#cnxn.close()
# Out:
# [(1, 'WALM003', 'San Antonio', 'Health and beauty', Decimal('74.6900'), 7, datetime.date(2019, 1, 5), datetime.time(13, 8), 'Ewallet', 9.100000381469727, datetime.time(0, 48), Decimal('522.83')), (2, 'WALM048', 'Harlingen', 'Electronic accessories', Decimal('15.2800'), 5, datetime.date(2019, 3, 8), datetime.time(10, 29), 'Cash', 9.600000381469727, datetime.time(0, 48), Decimal('76.40')), (3, 'WALM067', 'Haltom City', 'Home and lifestyle', Decimal('46.3300'), 7, datetime.date(2019, 3, 3), datetime.time(13, 23), 'Credit card', 7.400000095367432, datetime.time(0, 33), Decimal('324.31')), (4, 'WALM064', 'Bedford', 'Health and beauty', Decimal('58.2200'), 8, datetime.date(2019, 1, 27), datetime.time(20, 33), 'Ewallet', 8.399999618530273, datetime.time(0, 33), Decimal('465.76')), (5, 'WALM013', 'Irving', 'Sports and travel', Decimal('86.3100'), 7, datetime.date(2019, 2, 8), datetime.time(10, 37), 'Ewallet', 5.300000190734863, datetime.time(0, 48), Decimal('604.17')), (6, 'WALM026', 'Denton
# ...

# %%
cnxn.close()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9969 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      9969 non-null   int64
#  1   branch          9969 non-null   object
#  2   city            9969 non-null   object
#  3   category        9969 non-null   object
#  4   unit_price      9969 non-null   float64
#  5   quantity        9969 non-null   float64
#  6   date            9969 non-null   datetime64[ns]
#  7   time            9969 non-null   object
#  8   payment_method  9969 non-null   object
#  9   rating          9969 non-null   float64
#  10  profit_margin   9969 non-null   float64
#  11  day             9969 non-null   int32
#  12  month           9969 non-null   object
#  13  quarter         9969 non-null   int32
#  14  total           9969 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int32(2), int64(1), object(6)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#    invoice_id   branch         city                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity       date      time payment_method  rating  profit_margin  day  \
# 0       7.0 2019-01-05  13:08:00        Ewallet     9.1           0.48    5
# 1       5.0 2019-03-08  10:29:00           Cash     9.6           0.48    8
# 2       7.0 2019-03-03  13:23:00    Credit card     7.4           0.33    3
# 3       8.0 2019-01-27  20:33:00        Ewallet     8.4           0.33   27
# 4       7.0 2019-02-08  10:37:00        Ewallet     5.3           0.48    8
#
#       month  quarter   total
# 0   January        1  522.83
# ...

# %%
#insert_query = """
#Insert INTO [dbo].[employee]
             #([employee_id]
             #,[first_name]
             #,[last_name]
             #,[email]
             #,[hire_date]
             #,[salary]
              
#VALUES(?,?,?,?,?,?)
#"""

#data = (6,'kajal','sharma','k@gmail.com','2025-01-30',55000.00)

# %%
#cursor.execute(insert_query, data)
#cnxn.commit()

# %%
#cursor.close()

# %%
#cnxn.close()

# %%
#Perform this task
#Create a Schema
#Create a table
#Insert table
#Update the table
#Truncate the table
#delete the table

# %%
#Categorical Features
